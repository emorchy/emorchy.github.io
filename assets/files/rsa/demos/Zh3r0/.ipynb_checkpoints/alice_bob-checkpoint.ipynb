# %% [markdown]
#  Alice and Bob are sending their flags to Dave. But sadly Dave lost the modulus :( Try to retrive the flag!

# %% [markdown]
# $d \equiv e^{-1}\mod{\phi(n)}$
#
# $C \equiv m^e\mod n$
#
# $M \equiv C^d \mod n$

# %%
ct_a=...
ct_b=...
d_a=...
d_b=...
e=65537

# %% [markdown]
# $C_a = m_a^e \mod pq$
#
# $C_b = m_b^e \mod pr$

# %% [markdown]
# Assuming M is the same for both:
#
# $m \equiv C_a^{d_a} \mod pq \equiv C_b^{d_b} \mod pr$

# %% [markdown]
# $\phi(n_a) = (p-1)(q-1)$

# %% [markdown]
# $\phi(n_b) = (p-1)(r-1)$

# %% [markdown]
# $\frac{\phi(n_a)}{(q-1)} = \frac{\phi(n_b)}{(r-1)}$

# %% [markdown]
# $$de \equiv 1 \mod \phi(n)$$

# %% [markdown]
# $d_ae \equiv 1 \mod \phi(n_a)$
#
# $d_be \equiv 1 \mod \phi(n_b)$

# %%
d_a * e
d_b * e
# Out:
# ...

# %% [markdown]
# $m_a^{e_a} \times m_b^{e_b}$

# %% [markdown]
# $a \mod n = 5$
#
# $(a*b) \mod n = 5$
#
# $(a \mod n * b \mod n) \mod n \equiv (ab) \mod n$

# %% [markdown]
# $5 * 4 \mod (6 * 3) = 2$
#
# $5 * 4 \mod (6 * 9) = 20$
#
# $2 \mod 6 = 2$
#
# $20 \mod 6 = 2$

# %% [markdown]
# $gcd(C_a,m^e)$ = $gcd(C_b,m^e)$

# %% [markdown]
# $C_a \mod pq \equiv C_b \mod pr$
